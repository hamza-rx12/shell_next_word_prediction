# %% [markdown]
# Some libraries to import

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dropout, Dense
from sklearn.model_selection import train_test_split
import numpy as np
# Out:
# 2024-12-11 21:01:04.035905: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-11 21:01:04.045777: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733947264.057979  143017 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733947264.061670  143017 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-11 21:01:04.073365: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Choosing to work with the GPU for faster training

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')  # Use only the first GPU
    except RuntimeError as e:
        print(e)
# Out:
# 2024-12-11 21:01:09.491264: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2024-12-11 21:01:09.491286: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:137] retrieving CUDA diagnostic information for host: natsu
# 2024-12-11 21:01:09.491290: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:144] hostname: natsu
# 2024-12-11 21:01:09.491413: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:168] libcuda reported version is: 550.120.0
# 2024-12-11 21:01:09.491430: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:172] kernel reported version is: 550.120.0
# 2024-12-11 21:01:09.491434: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:259] kernel version seems to match DSO: 550.120.0

# %% [markdown]
# Importing data

# %%
commands = []

with open('data.txt', 'r') as file:
    for line in file:
      if line:
        commands.append(line.strip())

# commands

# %% [markdown]
# Tokenization

# %%
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts(commands)

# %% [markdown]
# Sequencing

# %%
sequences = tokenizer.texts_to_sequences(commands)
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1

# %% [markdown]
# Input Output sequences

# %%
input_sequences = []
target_sequences = []

for seq in sequences:
    for i in range(1, len(seq)):
        input_sequences.append(seq[:i])
        target_sequences.append(seq[i])

# %% [markdown]
# Padding

# %%
max_seq_len = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='post')
target_sequences = np.array(target_sequences)

# %% [markdown]
# Train_text spliting

# %%
x_train, x_test, y_train, y_test = train_test_split(input_sequences,target_sequences, test_size=0.2)

# %% [markdown]
# Model parameters

# %%
embedding_dim = 50
rnn_units = 64

# %% [markdown]
# Model building

# %%
model = Sequential([
    Embedding(vocab_size, embedding_dim, input_length=max_seq_len),
    SimpleRNN(rnn_units, return_sequences=False),
    Dropout(0.2),
    Dense(vocab_size, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# /home/natsu/Desktop/github-repos/shell_next_word_prediction/.env/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Fitting to data

# %%
history = model.fit(x_train, y_train, epochs=150, batch_size=16, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0493 - loss: 6.2392 - val_accuracy: 0.1244 - val_loss: 5.0640
# Epoch 2/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1536 - loss: 4.8331 - val_accuracy: 0.2365 - val_loss: 4.4573
# Epoch 3/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2235 - loss: 4.2257 - val_accuracy: 0.2691 - val_loss: 4.1187
# Epoch 4/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2599 - loss: 3.8796 - val_accuracy: 0.2946 - val_loss: 3.8972
# Epoch 5/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2808 - loss: 3.6727 - val_accuracy: 0.3114 - val_loss: 3.7286
# Epoch 6/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.2991 - loss: 3.4674 - val_accuracy: 0.3272 - val_loss: 3.6712
# Epoch 7/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3085 - loss: 3.3219 - val_accuracy: 0.3272 - val_loss: 3.5214
# Epoch 8/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3059 - loss: 3.2227 - val_accuracy: 0.3496 - val_loss: 3.4168
# Epoch 9/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3224 - loss: 3.1088 - val_accuracy: 0.3547 - val_loss: 3.3599
# Epoch 10/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3300 - loss: 3.0647 - val_accuracy: 0.3522 - val_loss: 3.2687
# Epoch 11/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3377 - loss: 2.9760 - val_accuracy: 0.3578 - val_loss: 3.2471
# Epoch 12/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3320 - loss: 2.9270 - val_accuracy: 0.3700 - val_loss: 3.1787
# Epoch 13/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3489 - loss: 2.8598 - val_accuracy: 0.3624 - val_loss: 3.1473
# Epoch 14/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3567 - loss: 2.7739 - val_accuracy: 0.3751 - val_loss: 3.1556
# Epoch 15/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3548 - loss: 2.7570 - val_accuracy: 0.3675 - val_loss: 3.1050
# Epoch 16/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3569 - loss: 2.7333 - val_accuracy: 0.3614 - val_loss: 3.0706
# Epoch 17/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3581 - loss: 2.6959 - val_accuracy: 0.3629 - val_loss: 3.1388
# Epoch 18/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3647 - loss: 2.6624 - val_accuracy: 0.3741 - val_loss: 3.0169
# Epoch 19/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3640 - loss: 2.6190 - val_accuracy: 0.3960 - val_loss: 2.9766
# Epoch 20/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3866 - loss: 2.5677 - val_accuracy: 0.3970 - val_loss: 2.9447
# Epoch 21/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.3594 - loss: 2.6362 - val_accuracy: 0.3823 - val_loss: 2.9414
# Epoch 22/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3696 - loss: 2.5703 - val_accuracy: 0.4001 - val_loss: 2.9016
# Epoch 23/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3787 - loss: 2.5234 - val_accuracy: 0.3955 - val_loss: 2.9014
# Epoch 24/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3798 - loss: 2.5000 - val_accuracy: 0.3884 - val_loss: 2.9176
# Epoch 25/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3862 - loss: 2.4941 - val_accuracy: 0.4001 - val_loss: 2.8762
# Epoch 26/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3865 - loss: 2.4423 - val_accuracy: 0.4083 - val_loss: 2.8746
# Epoch 27/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3896 - loss: 2.4307 - val_accuracy: 0.3945 - val_loss: 2.8943
# Epoch 28/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3870 - loss: 2.4945 - val_accuracy: 0.4108 - val_loss: 2.8462
# Epoch 29/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.3986 - loss: 2.4036 - val_accuracy: 0.4088 - val_loss: 2.8450
# Epoch 30/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3986 - loss: 2.3649 - val_accuracy: 0.4103 - val_loss: 2.8122
# Epoch 31/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4058 - loss: 2.3729 - val_accuracy: 0.3818 - val_loss: 2.9014
# Epoch 32/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.3981 - loss: 2.3976 - val_accuracy: 0.4134 - val_loss: 2.7842
# Epoch 33/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4169 - loss: 2.3000 - val_accuracy: 0.4276 - val_loss: 2.7744
# Epoch 34/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4137 - loss: 2.2899 - val_accuracy: 0.4047 - val_loss: 2.7928
# Epoch 35/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4132 - loss: 2.3060 - val_accuracy: 0.3981 - val_loss: 2.7986
# Epoch 36/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4105 - loss: 2.2858 - val_accuracy: 0.4266 - val_loss: 2.7492
# Epoch 37/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4223 - loss: 2.2822 - val_accuracy: 0.4266 - val_loss: 2.7320
# Epoch 38/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4219 - loss: 2.2920 - val_accuracy: 0.4123 - val_loss: 2.7495
# Epoch 39/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4112 - loss: 2.2799 - val_accuracy: 0.4261 - val_loss: 2.7383
# Epoch 40/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4322 - loss: 2.2145 - val_accuracy: 0.4337 - val_loss: 2.7223
# Epoch 41/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4280 - loss: 2.2013 - val_accuracy: 0.4225 - val_loss: 2.7199
# Epoch 42/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4299 - loss: 2.1989 - val_accuracy: 0.4210 - val_loss: 2.7179
# Epoch 43/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4321 - loss: 2.2092 - val_accuracy: 0.4062 - val_loss: 2.8431
# Epoch 44/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4150 - loss: 2.2816 - val_accuracy: 0.4434 - val_loss: 2.6759
# Epoch 45/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4380 - loss: 2.2062 - val_accuracy: 0.4404 - val_loss: 2.6634
# Epoch 46/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4290 - loss: 2.1975 - val_accuracy: 0.4266 - val_loss: 2.6860
# Epoch 47/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4332 - loss: 2.2012 - val_accuracy: 0.4363 - val_loss: 2.6832
# Epoch 48/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4342 - loss: 2.1961 - val_accuracy: 0.4444 - val_loss: 2.6647
# Epoch 49/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4410 - loss: 2.1808 - val_accuracy: 0.4373 - val_loss: 2.6613
# Epoch 50/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4467 - loss: 2.1406 - val_accuracy: 0.4419 - val_loss: 2.6518
# Epoch 51/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4501 - loss: 2.1146 - val_accuracy: 0.4353 - val_loss: 2.6901
# Epoch 52/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4392 - loss: 2.1414 - val_accuracy: 0.4399 - val_loss: 2.6574
# Epoch 53/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4449 - loss: 2.1180 - val_accuracy: 0.4343 - val_loss: 2.6420
# Epoch 54/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4442 - loss: 2.1292 - val_accuracy: 0.4337 - val_loss: 2.6771
# Epoch 55/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4428 - loss: 2.1369 - val_accuracy: 0.4297 - val_loss: 2.6678
# Epoch 56/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4474 - loss: 2.1134 - val_accuracy: 0.4444 - val_loss: 2.6552
# Epoch 57/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4368 - loss: 2.1218 - val_accuracy: 0.4388 - val_loss: 2.6430
# Epoch 58/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4536 - loss: 2.0958 - val_accuracy: 0.4393 - val_loss: 2.6889
# Epoch 59/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4573 - loss: 2.0760 - val_accuracy: 0.4480 - val_loss: 2.6421
# Epoch 60/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4484 - loss: 2.0991 - val_accuracy: 0.4439 - val_loss: 2.6477
# Epoch 61/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4519 - loss: 2.0884 - val_accuracy: 0.4531 - val_loss: 2.6022
# Epoch 62/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4500 - loss: 2.0871 - val_accuracy: 0.4434 - val_loss: 2.6321
# Epoch 63/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4589 - loss: 2.0701 - val_accuracy: 0.4378 - val_loss: 2.6029
# Epoch 64/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4626 - loss: 2.0448 - val_accuracy: 0.4393 - val_loss: 2.6490
# Epoch 65/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4510 - loss: 2.1099 - val_accuracy: 0.4521 - val_loss: 2.6358
# Epoch 66/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4591 - loss: 2.0625 - val_accuracy: 0.4419 - val_loss: 2.5964
# Epoch 67/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4584 - loss: 2.0138 - val_accuracy: 0.4404 - val_loss: 2.6091
# Epoch 68/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4631 - loss: 2.0316 - val_accuracy: 0.4210 - val_loss: 2.7734
# Epoch 69/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4373 - loss: 2.1415 - val_accuracy: 0.4475 - val_loss: 2.5782
# Epoch 70/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4718 - loss: 1.9934 - val_accuracy: 0.4373 - val_loss: 2.6562
# Epoch 71/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4553 - loss: 2.0520 - val_accuracy: 0.4470 - val_loss: 2.6136
# Epoch 72/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4720 - loss: 2.0055 - val_accuracy: 0.4506 - val_loss: 2.5604
# Epoch 73/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4573 - loss: 2.0287 - val_accuracy: 0.4521 - val_loss: 2.5671
# Epoch 74/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4551 - loss: 2.0591 - val_accuracy: 0.4648 - val_loss: 2.5780
# Epoch 75/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4797 - loss: 2.0157 - val_accuracy: 0.4516 - val_loss: 2.5805
# Epoch 76/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4617 - loss: 2.0248 - val_accuracy: 0.4546 - val_loss: 2.5477
# Epoch 77/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4677 - loss: 1.9962 - val_accuracy: 0.4465 - val_loss: 2.5550
# Epoch 78/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4646 - loss: 1.9953 - val_accuracy: 0.4495 - val_loss: 2.5566
# Epoch 79/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4575 - loss: 2.0172 - val_accuracy: 0.4557 - val_loss: 2.5791
# Epoch 80/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4618 - loss: 2.0385 - val_accuracy: 0.4511 - val_loss: 2.5651
# Epoch 81/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4748 - loss: 1.9829 - val_accuracy: 0.4546 - val_loss: 2.5461
# Epoch 82/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4734 - loss: 1.9755 - val_accuracy: 0.4602 - val_loss: 2.5382
# Epoch 83/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4702 - loss: 1.9736 - val_accuracy: 0.4526 - val_loss: 2.5617
# Epoch 84/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4622 - loss: 2.0178 - val_accuracy: 0.4531 - val_loss: 2.5692
# Epoch 85/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4607 - loss: 2.0208 - val_accuracy: 0.4613 - val_loss: 2.5353
# Epoch 86/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4694 - loss: 1.9696 - val_accuracy: 0.4455 - val_loss: 2.5335
# Epoch 87/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4846 - loss: 1.9452 - val_accuracy: 0.4501 - val_loss: 2.5490
# Epoch 88/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4602 - loss: 1.9783 - val_accuracy: 0.4541 - val_loss: 2.5506
# Epoch 89/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4734 - loss: 1.9395 - val_accuracy: 0.4613 - val_loss: 2.5177
# Epoch 90/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4779 - loss: 1.9199 - val_accuracy: 0.4633 - val_loss: 2.5413
# Epoch 91/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4659 - loss: 1.9588 - val_accuracy: 0.4699 - val_loss: 2.5259
# Epoch 92/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4784 - loss: 1.9468 - val_accuracy: 0.4506 - val_loss: 2.5521
# Epoch 93/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4778 - loss: 1.9475 - val_accuracy: 0.4388 - val_loss: 2.6462
# Epoch 94/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4709 - loss: 1.9543 - val_accuracy: 0.4684 - val_loss: 2.5033
# Epoch 95/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4715 - loss: 1.9749 - val_accuracy: 0.4613 - val_loss: 2.5448
# Epoch 96/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4676 - loss: 1.9819 - val_accuracy: 0.4592 - val_loss: 2.5311
# Epoch 97/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4798 - loss: 1.9162 - val_accuracy: 0.4709 - val_loss: 2.5037
# Epoch 98/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4792 - loss: 1.9439 - val_accuracy: 0.4786 - val_loss: 2.5089
# Epoch 99/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4783 - loss: 1.9538 - val_accuracy: 0.4643 - val_loss: 2.5288
# Epoch 100/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4504 - loss: 2.0862 - val_accuracy: 0.4531 - val_loss: 2.5169
# Epoch 101/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4714 - loss: 1.9719 - val_accuracy: 0.4546 - val_loss: 2.5573
# Epoch 102/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4788 - loss: 1.9319 - val_accuracy: 0.4674 - val_loss: 2.4888
# Epoch 103/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4712 - loss: 1.9576 - val_accuracy: 0.4715 - val_loss: 2.5130
# Epoch 104/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4752 - loss: 1.9093 - val_accuracy: 0.4694 - val_loss: 2.4948
# Epoch 105/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4786 - loss: 1.9124 - val_accuracy: 0.4699 - val_loss: 2.4959
# Epoch 106/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4955 - loss: 1.8462 - val_accuracy: 0.4704 - val_loss: 2.4853
# Epoch 107/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4664 - loss: 2.0236 - val_accuracy: 0.4358 - val_loss: 2.6909
# Epoch 108/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4667 - loss: 2.0163 - val_accuracy: 0.4648 - val_loss: 2.4740
# Epoch 109/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4837 - loss: 1.9181 - val_accuracy: 0.4679 - val_loss: 2.4733
# Epoch 110/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4947 - loss: 1.8761 - val_accuracy: 0.4715 - val_loss: 2.4827
# Epoch 111/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4900 - loss: 1.8809 - val_accuracy: 0.4806 - val_loss: 2.4620
# Epoch 112/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4826 - loss: 1.9054 - val_accuracy: 0.4694 - val_loss: 2.4688
# Epoch 113/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4941 - loss: 1.8842 - val_accuracy: 0.4373 - val_loss: 2.6836
# Epoch 114/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4608 - loss: 2.0404 - val_accuracy: 0.4674 - val_loss: 2.5047
# Epoch 115/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4773 - loss: 1.9260 - val_accuracy: 0.4659 - val_loss: 2.5529
# Epoch 116/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4883 - loss: 1.9003 - val_accuracy: 0.4760 - val_loss: 2.5102
# Epoch 117/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4764 - loss: 1.9634 - val_accuracy: 0.4709 - val_loss: 2.4888
# Epoch 118/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4878 - loss: 1.8985 - val_accuracy: 0.4720 - val_loss: 2.4774
# Epoch 119/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4857 - loss: 1.8976 - val_accuracy: 0.4699 - val_loss: 2.4687
# Epoch 120/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5027 - loss: 1.8890 - val_accuracy: 0.4562 - val_loss: 2.4865
# Epoch 121/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4771 - loss: 1.9112 - val_accuracy: 0.4694 - val_loss: 2.4814
# Epoch 122/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4915 - loss: 1.8616 - val_accuracy: 0.4811 - val_loss: 2.4846
# Epoch 123/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4744 - loss: 1.9475 - val_accuracy: 0.4577 - val_loss: 2.5057
# Epoch 124/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4771 - loss: 1.9595 - val_accuracy: 0.4684 - val_loss: 2.4806
# Epoch 125/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4887 - loss: 1.9184 - val_accuracy: 0.4766 - val_loss: 2.4955
# Epoch 126/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4800 - loss: 1.9102 - val_accuracy: 0.4720 - val_loss: 2.4875
# Epoch 127/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4897 - loss: 1.8954 - val_accuracy: 0.4669 - val_loss: 2.5078
# Epoch 128/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4847 - loss: 1.8816 - val_accuracy: 0.4740 - val_loss: 2.4855
# Epoch 129/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4806 - loss: 1.9124 - val_accuracy: 0.4546 - val_loss: 2.5354
# Epoch 130/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4529 - loss: 2.1356 - val_accuracy: 0.4495 - val_loss: 2.5861
# Epoch 131/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4571 - loss: 1.9880 - val_accuracy: 0.4760 - val_loss: 2.4744
# Epoch 132/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4940 - loss: 1.8611 - val_accuracy: 0.4730 - val_loss: 2.4712
# Epoch 133/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4914 - loss: 1.8757 - val_accuracy: 0.4679 - val_loss: 2.4693
# Epoch 134/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4913 - loss: 1.8736 - val_accuracy: 0.4720 - val_loss: 2.4772
# Epoch 135/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4883 - loss: 1.8667 - val_accuracy: 0.4699 - val_loss: 2.4954
# Epoch 136/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4845 - loss: 1.8895 - val_accuracy: 0.4582 - val_loss: 2.4825
# Epoch 137/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4984 - loss: 1.8721 - val_accuracy: 0.4715 - val_loss: 2.4817
# Epoch 138/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.4899 - loss: 1.8574 - val_accuracy: 0.4720 - val_loss: 2.4536
# Epoch 139/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.5091 - loss: 1.8283 - val_accuracy: 0.4618 - val_loss: 2.5228
# Epoch 140/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4888 - loss: 1.8912 - val_accuracy: 0.4638 - val_loss: 2.4809
# Epoch 141/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.4919 - loss: 1.8816 - val_accuracy: 0.4577 - val_loss: 2.5522
# Epoch 142/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4872 - loss: 1.9486 - val_accuracy: 0.4689 - val_loss: 2.4742
# Epoch 143/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4823 - loss: 1.9164 - val_accuracy: 0.4766 - val_loss: 2.4473
# Epoch 144/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.4949 - loss: 1.8528 - val_accuracy: 0.4852 - val_loss: 2.4728
# Epoch 145/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4949 - loss: 1.8767 - val_accuracy: 0.4628 - val_loss: 2.5206
# Epoch 146/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4815 - loss: 1.9348 - val_accuracy: 0.4618 - val_loss: 2.4783
# Epoch 147/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.4795 - loss: 1.9098 - val_accuracy: 0.4776 - val_loss: 2.4541
# Epoch 148/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.5001 - loss: 1.8531 - val_accuracy: 0.4771 - val_loss: 2.4571
# Epoch 149/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.4968 - loss: 1.8525 - val_accuracy: 0.4699 - val_loss: 2.4484
# Epoch 150/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.5025 - loss: 1.8360 - val_accuracy: 0.4771 - val_loss: 2.5055

# %% [markdown]
# Extraction statistics

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

epochs = range(1, len(train_loss) + 1)

# %% [markdown]
# Graphs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss During Training and Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy During Training and Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Saving the model

# %%
model.save("rnn_model.keras")

# %% [markdown]
# Saving the tokenizer

# %%
import pickle

with open("rnn_tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)

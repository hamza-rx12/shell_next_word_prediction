# %% [markdown]
# Some libraries to import

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dropout, Dense
from sklearn.model_selection import train_test_split
import numpy as np
# Out:
# 2024-12-24 22:34:34.932391: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-24 22:34:34.942442: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1735076074.954466   71640 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1735076074.958301   71640 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-24 22:34:34.969915: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Choosing to work with the GPU for faster training

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')  # Use only the first GPU
    except RuntimeError as e:
        print(e)
# Out:
# W0000 00:00:1735076076.914137   71640 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# Importing data

# %%
commands = []

with open('data.txt', 'r') as file:
    for line in file:
      if line:
        commands.append(line.strip())

# commands

# %% [markdown]
# Tokenization

# %%
tokenizer = Tokenizer(filters='')
tokenizer.fit_on_texts(commands)

# %% [markdown]
# Sequencing

# %%
sequences = tokenizer.texts_to_sequences(commands)
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1

# %% [markdown]
# Input Output sequences

# %%
input_sequences = []
target_sequences = []

for seq in sequences:
    for i in range(1, len(seq)):
        input_sequences.append(seq[:i])
        target_sequences.append(seq[i])

# %% [markdown]
# Padding

# %%
max_seq_len = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_seq_len, padding='post')
target_sequences = np.array(target_sequences)

# %% [markdown]
# Train_text spliting

# %%
x_train, x_test, y_train, y_test = train_test_split(input_sequences,target_sequences, test_size=0.2)

# %% [markdown]
# Parameter loading

# %%
import configparser
################
# reading 
################
config = configparser.ConfigParser()
config.read('best_hyperparameters.ini')

# Access hyperparameters
embedding_dim = config.getint('Hyperparameters', 'embedding_dim')
rnn_units = config.getint('Hyperparameters', 'rnn_units')
dropout_rate = config.getfloat('Hyperparameters', 'dropout_rate')
learning_rate = config.getfloat('Hyperparameters', 'learning_rate')
batch_size = config.getint('Hyperparameters', 'batch_size')
top_k = config.getint('Hyperparameters', 'top_k')
activation = config.get('Hyperparameters', 'activation')
activation
# Out:
# 'softmax'

# %% [markdown]
# Model building

# %%
model = Sequential([
    Embedding(vocab_size, embedding_dim, input_length=max_seq_len),
    SimpleRNN(rnn_units, return_sequences=False),
    Dropout(dropout_rate),
    Dense(vocab_size, activation=activation)
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), 
    loss='sparse_categorical_crossentropy', 
    metrics=[tf.keras.metrics.SparseTopKCategoricalAccuracy(k=top_k)])
model.summary()
# Out:
# /home/natsu/Desktop/shell_next_word_prediction/rnn/.rnn/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Fitting to data

# %%
history = model.fit(x_train, y_train, epochs=150, batch_size=batch_size, verbose=1, validation_data=(x_test, y_test))
# Out:
# Epoch 1/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 6.0958 - sparse_top_k_categorical_accuracy: 0.1740 - val_loss: 4.8636 - val_sparse_top_k_categorical_accuracy: 0.3277
# Epoch 2/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4.5805 - sparse_top_k_categorical_accuracy: 0.3699 - val_loss: 4.2226 - val_sparse_top_k_categorical_accuracy: 0.4378
# Epoch 3/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 4.0530 - sparse_top_k_categorical_accuracy: 0.4300 - val_loss: 3.9514 - val_sparse_top_k_categorical_accuracy: 0.4715
# Epoch 4/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.7172 - sparse_top_k_categorical_accuracy: 0.4768 - val_loss: 3.7033 - val_sparse_top_k_categorical_accuracy: 0.5076
# Epoch 5/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 3.4605 - sparse_top_k_categorical_accuracy: 0.5116 - val_loss: 3.5590 - val_sparse_top_k_categorical_accuracy: 0.5316
# Epoch 6/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.2705 - sparse_top_k_categorical_accuracy: 0.5399 - val_loss: 3.4150 - val_sparse_top_k_categorical_accuracy: 0.5540
# Epoch 7/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.1411 - sparse_top_k_categorical_accuracy: 0.5646 - val_loss: 3.3313 - val_sparse_top_k_categorical_accuracy: 0.5683
# Epoch 8/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 3.0408 - sparse_top_k_categorical_accuracy: 0.5770 - val_loss: 3.2036 - val_sparse_top_k_categorical_accuracy: 0.5872
# Epoch 9/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.8822 - sparse_top_k_categorical_accuracy: 0.6019 - val_loss: 3.1972 - val_sparse_top_k_categorical_accuracy: 0.5765
# Epoch 10/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.8579 - sparse_top_k_categorical_accuracy: 0.6103 - val_loss: 3.1169 - val_sparse_top_k_categorical_accuracy: 0.5994
# Epoch 11/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.7796 - sparse_top_k_categorical_accuracy: 0.6151 - val_loss: 3.0724 - val_sparse_top_k_categorical_accuracy: 0.6040
# Epoch 12/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.7130 - sparse_top_k_categorical_accuracy: 0.6255 - val_loss: 2.9785 - val_sparse_top_k_categorical_accuracy: 0.6218
# Epoch 13/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.6087 - sparse_top_k_categorical_accuracy: 0.6464 - val_loss: 3.0739 - val_sparse_top_k_categorical_accuracy: 0.6030
# Epoch 14/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.6685 - sparse_top_k_categorical_accuracy: 0.6421 - val_loss: 2.9059 - val_sparse_top_k_categorical_accuracy: 0.6351
# Epoch 15/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.5470 - sparse_top_k_categorical_accuracy: 0.6551 - val_loss: 2.8806 - val_sparse_top_k_categorical_accuracy: 0.6381
# Epoch 16/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.5221 - sparse_top_k_categorical_accuracy: 0.6661 - val_loss: 2.8811 - val_sparse_top_k_categorical_accuracy: 0.6340
# Epoch 17/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 2.4662 - sparse_top_k_categorical_accuracy: 0.6727 - val_loss: 2.8253 - val_sparse_top_k_categorical_accuracy: 0.6549
# Epoch 18/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.4365 - sparse_top_k_categorical_accuracy: 0.6866 - val_loss: 2.7889 - val_sparse_top_k_categorical_accuracy: 0.6463
# Epoch 19/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.3589 - sparse_top_k_categorical_accuracy: 0.7021 - val_loss: 2.7551 - val_sparse_top_k_categorical_accuracy: 0.6626
# Epoch 20/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.3649 - sparse_top_k_categorical_accuracy: 0.6958 - val_loss: 2.7394 - val_sparse_top_k_categorical_accuracy: 0.6667
# Epoch 21/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.3430 - sparse_top_k_categorical_accuracy: 0.7005 - val_loss: 2.7528 - val_sparse_top_k_categorical_accuracy: 0.6713
# Epoch 22/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.3105 - sparse_top_k_categorical_accuracy: 0.7024 - val_loss: 2.7366 - val_sparse_top_k_categorical_accuracy: 0.6769
# Epoch 23/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.3231 - sparse_top_k_categorical_accuracy: 0.7044 - val_loss: 2.6639 - val_sparse_top_k_categorical_accuracy: 0.6789
# Epoch 24/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.2276 - sparse_top_k_categorical_accuracy: 0.7183 - val_loss: 2.6449 - val_sparse_top_k_categorical_accuracy: 0.6840
# Epoch 25/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.2313 - sparse_top_k_categorical_accuracy: 0.7204 - val_loss: 2.6064 - val_sparse_top_k_categorical_accuracy: 0.7054
# Epoch 26/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.1607 - sparse_top_k_categorical_accuracy: 0.7363 - val_loss: 2.6069 - val_sparse_top_k_categorical_accuracy: 0.7034
# Epoch 27/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.1915 - sparse_top_k_categorical_accuracy: 0.7309 - val_loss: 2.6475 - val_sparse_top_k_categorical_accuracy: 0.6820
# Epoch 28/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.1530 - sparse_top_k_categorical_accuracy: 0.7413 - val_loss: 2.6435 - val_sparse_top_k_categorical_accuracy: 0.7013
# Epoch 29/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.1904 - sparse_top_k_categorical_accuracy: 0.7354 - val_loss: 2.5912 - val_sparse_top_k_categorical_accuracy: 0.7044
# Epoch 30/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0919 - sparse_top_k_categorical_accuracy: 0.7490 - val_loss: 2.5759 - val_sparse_top_k_categorical_accuracy: 0.7049
# Epoch 31/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0892 - sparse_top_k_categorical_accuracy: 0.7472 - val_loss: 2.5548 - val_sparse_top_k_categorical_accuracy: 0.7161
# Epoch 32/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0878 - sparse_top_k_categorical_accuracy: 0.7514 - val_loss: 2.5834 - val_sparse_top_k_categorical_accuracy: 0.7085
# Epoch 33/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0506 - sparse_top_k_categorical_accuracy: 0.7601 - val_loss: 2.5471 - val_sparse_top_k_categorical_accuracy: 0.7207
# Epoch 34/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0240 - sparse_top_k_categorical_accuracy: 0.7635 - val_loss: 2.5507 - val_sparse_top_k_categorical_accuracy: 0.7319
# Epoch 35/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0431 - sparse_top_k_categorical_accuracy: 0.7561 - val_loss: 2.4934 - val_sparse_top_k_categorical_accuracy: 0.7294
# Epoch 36/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0277 - sparse_top_k_categorical_accuracy: 0.7569 - val_loss: 2.4803 - val_sparse_top_k_categorical_accuracy: 0.7314
# Epoch 37/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9778 - sparse_top_k_categorical_accuracy: 0.7670 - val_loss: 2.4721 - val_sparse_top_k_categorical_accuracy: 0.7396
# Epoch 38/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0033 - sparse_top_k_categorical_accuracy: 0.7651 - val_loss: 2.5246 - val_sparse_top_k_categorical_accuracy: 0.7263
# Epoch 39/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0306 - sparse_top_k_categorical_accuracy: 0.7663 - val_loss: 2.4510 - val_sparse_top_k_categorical_accuracy: 0.7472
# Epoch 40/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9487 - sparse_top_k_categorical_accuracy: 0.7754 - val_loss: 2.4350 - val_sparse_top_k_categorical_accuracy: 0.7538
# Epoch 41/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9952 - sparse_top_k_categorical_accuracy: 0.7659 - val_loss: 2.4783 - val_sparse_top_k_categorical_accuracy: 0.7406
# Epoch 42/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 2.0094 - sparse_top_k_categorical_accuracy: 0.7665 - val_loss: 2.4541 - val_sparse_top_k_categorical_accuracy: 0.7523
# Epoch 43/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9238 - sparse_top_k_categorical_accuracy: 0.7826 - val_loss: 2.4369 - val_sparse_top_k_categorical_accuracy: 0.7589
# Epoch 44/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9256 - sparse_top_k_categorical_accuracy: 0.7816 - val_loss: 2.4347 - val_sparse_top_k_categorical_accuracy: 0.7584
# Epoch 45/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9394 - sparse_top_k_categorical_accuracy: 0.7847 - val_loss: 2.4786 - val_sparse_top_k_categorical_accuracy: 0.7467
# Epoch 46/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9102 - sparse_top_k_categorical_accuracy: 0.7841 - val_loss: 2.4594 - val_sparse_top_k_categorical_accuracy: 0.7467
# Epoch 47/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9366 - sparse_top_k_categorical_accuracy: 0.7874 - val_loss: 2.4494 - val_sparse_top_k_categorical_accuracy: 0.7543
# Epoch 48/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9151 - sparse_top_k_categorical_accuracy: 0.7752 - val_loss: 2.4223 - val_sparse_top_k_categorical_accuracy: 0.7559
# Epoch 49/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8571 - sparse_top_k_categorical_accuracy: 0.7909 - val_loss: 2.4606 - val_sparse_top_k_categorical_accuracy: 0.7487
# Epoch 50/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8804 - sparse_top_k_categorical_accuracy: 0.7914 - val_loss: 2.4056 - val_sparse_top_k_categorical_accuracy: 0.7589
# Epoch 51/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9613 - sparse_top_k_categorical_accuracy: 0.7737 - val_loss: 2.4418 - val_sparse_top_k_categorical_accuracy: 0.7599
# Epoch 52/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 1.9455 - sparse_top_k_categorical_accuracy: 0.7876 - val_loss: 2.4645 - val_sparse_top_k_categorical_accuracy: 0.7559
# Epoch 53/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8793 - sparse_top_k_categorical_accuracy: 0.7977 - val_loss: 2.4115 - val_sparse_top_k_categorical_accuracy: 0.7650
# Epoch 54/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8607 - sparse_top_k_categorical_accuracy: 0.7950 - val_loss: 2.3787 - val_sparse_top_k_categorical_accuracy: 0.7661
# Epoch 55/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8202 - sparse_top_k_categorical_accuracy: 0.7948 - val_loss: 2.4540 - val_sparse_top_k_categorical_accuracy: 0.7584
# Epoch 56/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8620 - sparse_top_k_categorical_accuracy: 0.7908 - val_loss: 2.3811 - val_sparse_top_k_categorical_accuracy: 0.7737
# Epoch 57/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8717 - sparse_top_k_categorical_accuracy: 0.7883 - val_loss: 2.4432 - val_sparse_top_k_categorical_accuracy: 0.7768
# Epoch 58/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8642 - sparse_top_k_categorical_accuracy: 0.7931 - val_loss: 2.4305 - val_sparse_top_k_categorical_accuracy: 0.7635
# Epoch 59/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9033 - sparse_top_k_categorical_accuracy: 0.7844 - val_loss: 2.4200 - val_sparse_top_k_categorical_accuracy: 0.7543
# Epoch 60/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8310 - sparse_top_k_categorical_accuracy: 0.7940 - val_loss: 2.3669 - val_sparse_top_k_categorical_accuracy: 0.7676
# Epoch 61/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8235 - sparse_top_k_categorical_accuracy: 0.7965 - val_loss: 2.4224 - val_sparse_top_k_categorical_accuracy: 0.7564
# Epoch 62/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8613 - sparse_top_k_categorical_accuracy: 0.7885 - val_loss: 2.4272 - val_sparse_top_k_categorical_accuracy: 0.7574
# Epoch 63/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8351 - sparse_top_k_categorical_accuracy: 0.7954 - val_loss: 2.3903 - val_sparse_top_k_categorical_accuracy: 0.7706
# Epoch 64/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8409 - sparse_top_k_categorical_accuracy: 0.7974 - val_loss: 2.4079 - val_sparse_top_k_categorical_accuracy: 0.7696
# Epoch 65/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8744 - sparse_top_k_categorical_accuracy: 0.7939 - val_loss: 2.3949 - val_sparse_top_k_categorical_accuracy: 0.7701
# Epoch 66/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8673 - sparse_top_k_categorical_accuracy: 0.7907 - val_loss: 2.4536 - val_sparse_top_k_categorical_accuracy: 0.7462
# Epoch 67/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9079 - sparse_top_k_categorical_accuracy: 0.7842 - val_loss: 2.4479 - val_sparse_top_k_categorical_accuracy: 0.7635
# Epoch 68/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9071 - sparse_top_k_categorical_accuracy: 0.7806 - val_loss: 2.4359 - val_sparse_top_k_categorical_accuracy: 0.7666
# Epoch 69/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8969 - sparse_top_k_categorical_accuracy: 0.7863 - val_loss: 2.3921 - val_sparse_top_k_categorical_accuracy: 0.7798
# Epoch 70/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8230 - sparse_top_k_categorical_accuracy: 0.7882 - val_loss: 2.4002 - val_sparse_top_k_categorical_accuracy: 0.7691
# Epoch 71/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8480 - sparse_top_k_categorical_accuracy: 0.7946 - val_loss: 2.3699 - val_sparse_top_k_categorical_accuracy: 0.7752
# Epoch 72/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8209 - sparse_top_k_categorical_accuracy: 0.7948 - val_loss: 2.3780 - val_sparse_top_k_categorical_accuracy: 0.7737
# Epoch 73/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8105 - sparse_top_k_categorical_accuracy: 0.7993 - val_loss: 2.3701 - val_sparse_top_k_categorical_accuracy: 0.7701
# Epoch 74/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8195 - sparse_top_k_categorical_accuracy: 0.7880 - val_loss: 2.3460 - val_sparse_top_k_categorical_accuracy: 0.7768
# Epoch 75/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8065 - sparse_top_k_categorical_accuracy: 0.7903 - val_loss: 2.3683 - val_sparse_top_k_categorical_accuracy: 0.7757
# Epoch 76/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8005 - sparse_top_k_categorical_accuracy: 0.8021 - val_loss: 2.3994 - val_sparse_top_k_categorical_accuracy: 0.7696
# Epoch 77/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8547 - sparse_top_k_categorical_accuracy: 0.7956 - val_loss: 2.4255 - val_sparse_top_k_categorical_accuracy: 0.7696
# Epoch 78/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8711 - sparse_top_k_categorical_accuracy: 0.7891 - val_loss: 2.4040 - val_sparse_top_k_categorical_accuracy: 0.7655
# Epoch 79/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7982 - sparse_top_k_categorical_accuracy: 0.8007 - val_loss: 2.3342 - val_sparse_top_k_categorical_accuracy: 0.7762
# Epoch 80/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8013 - sparse_top_k_categorical_accuracy: 0.7978 - val_loss: 2.3968 - val_sparse_top_k_categorical_accuracy: 0.7671
# Epoch 81/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8331 - sparse_top_k_categorical_accuracy: 0.7875 - val_loss: 2.3730 - val_sparse_top_k_categorical_accuracy: 0.7813
# Epoch 82/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7858 - sparse_top_k_categorical_accuracy: 0.8002 - val_loss: 2.3713 - val_sparse_top_k_categorical_accuracy: 0.7793
# Epoch 83/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8609 - sparse_top_k_categorical_accuracy: 0.7902 - val_loss: 2.3591 - val_sparse_top_k_categorical_accuracy: 0.7793
# Epoch 84/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8137 - sparse_top_k_categorical_accuracy: 0.7950 - val_loss: 2.3673 - val_sparse_top_k_categorical_accuracy: 0.7732
# Epoch 85/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8232 - sparse_top_k_categorical_accuracy: 0.7888 - val_loss: 2.3969 - val_sparse_top_k_categorical_accuracy: 0.7727
# Epoch 86/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8476 - sparse_top_k_categorical_accuracy: 0.7921 - val_loss: 2.3707 - val_sparse_top_k_categorical_accuracy: 0.7742
# Epoch 87/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7633 - sparse_top_k_categorical_accuracy: 0.8036 - val_loss: 2.3746 - val_sparse_top_k_categorical_accuracy: 0.7732
# Epoch 88/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7795 - sparse_top_k_categorical_accuracy: 0.8001 - val_loss: 2.4286 - val_sparse_top_k_categorical_accuracy: 0.7681
# Epoch 89/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8619 - sparse_top_k_categorical_accuracy: 0.7895 - val_loss: 2.3213 - val_sparse_top_k_categorical_accuracy: 0.7773
# Epoch 90/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7535 - sparse_top_k_categorical_accuracy: 0.8041 - val_loss: 2.3602 - val_sparse_top_k_categorical_accuracy: 0.7655
# Epoch 91/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8304 - sparse_top_k_categorical_accuracy: 0.7991 - val_loss: 2.3406 - val_sparse_top_k_categorical_accuracy: 0.7773
# Epoch 92/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8070 - sparse_top_k_categorical_accuracy: 0.7907 - val_loss: 2.3549 - val_sparse_top_k_categorical_accuracy: 0.7747
# Epoch 93/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7730 - sparse_top_k_categorical_accuracy: 0.8022 - val_loss: 2.3615 - val_sparse_top_k_categorical_accuracy: 0.7742
# Epoch 94/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7884 - sparse_top_k_categorical_accuracy: 0.7965 - val_loss: 2.3422 - val_sparse_top_k_categorical_accuracy: 0.7773
# Epoch 95/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8030 - sparse_top_k_categorical_accuracy: 0.8035 - val_loss: 2.3804 - val_sparse_top_k_categorical_accuracy: 0.7742
# Epoch 96/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8065 - sparse_top_k_categorical_accuracy: 0.8031 - val_loss: 2.3609 - val_sparse_top_k_categorical_accuracy: 0.7762
# Epoch 97/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7487 - sparse_top_k_categorical_accuracy: 0.8032 - val_loss: 2.3900 - val_sparse_top_k_categorical_accuracy: 0.7686
# Epoch 98/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8026 - sparse_top_k_categorical_accuracy: 0.8009 - val_loss: 2.3903 - val_sparse_top_k_categorical_accuracy: 0.7681
# Epoch 99/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7796 - sparse_top_k_categorical_accuracy: 0.7981 - val_loss: 2.3378 - val_sparse_top_k_categorical_accuracy: 0.7722
# Epoch 100/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7874 - sparse_top_k_categorical_accuracy: 0.7995 - val_loss: 2.3514 - val_sparse_top_k_categorical_accuracy: 0.7783
# Epoch 101/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7656 - sparse_top_k_categorical_accuracy: 0.8028 - val_loss: 2.3298 - val_sparse_top_k_categorical_accuracy: 0.7762
# Epoch 102/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7805 - sparse_top_k_categorical_accuracy: 0.8012 - val_loss: 2.3912 - val_sparse_top_k_categorical_accuracy: 0.7701
# Epoch 103/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8194 - sparse_top_k_categorical_accuracy: 0.8049 - val_loss: 2.3750 - val_sparse_top_k_categorical_accuracy: 0.7747
# Epoch 104/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7964 - sparse_top_k_categorical_accuracy: 0.7928 - val_loss: 2.3430 - val_sparse_top_k_categorical_accuracy: 0.7773
# Epoch 105/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7560 - sparse_top_k_categorical_accuracy: 0.8053 - val_loss: 2.3128 - val_sparse_top_k_categorical_accuracy: 0.7732
# Epoch 106/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7397 - sparse_top_k_categorical_accuracy: 0.8065 - val_loss: 2.3262 - val_sparse_top_k_categorical_accuracy: 0.7813
# Epoch 107/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8330 - sparse_top_k_categorical_accuracy: 0.7884 - val_loss: 2.3759 - val_sparse_top_k_categorical_accuracy: 0.7706
# Epoch 108/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8075 - sparse_top_k_categorical_accuracy: 0.7976 - val_loss: 2.3789 - val_sparse_top_k_categorical_accuracy: 0.7696
# Epoch 109/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7903 - sparse_top_k_categorical_accuracy: 0.8045 - val_loss: 2.3526 - val_sparse_top_k_categorical_accuracy: 0.7768
# Epoch 110/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7733 - sparse_top_k_categorical_accuracy: 0.8059 - val_loss: 2.3568 - val_sparse_top_k_categorical_accuracy: 0.7732
# Epoch 111/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7761 - sparse_top_k_categorical_accuracy: 0.7999 - val_loss: 2.4040 - val_sparse_top_k_categorical_accuracy: 0.7569
# Epoch 112/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8305 - sparse_top_k_categorical_accuracy: 0.7943 - val_loss: 2.3382 - val_sparse_top_k_categorical_accuracy: 0.7824
# Epoch 113/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7904 - sparse_top_k_categorical_accuracy: 0.7960 - val_loss: 2.3947 - val_sparse_top_k_categorical_accuracy: 0.7635
# Epoch 114/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7618 - sparse_top_k_categorical_accuracy: 0.8082 - val_loss: 2.3408 - val_sparse_top_k_categorical_accuracy: 0.7768
# Epoch 115/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7726 - sparse_top_k_categorical_accuracy: 0.8004 - val_loss: 2.3335 - val_sparse_top_k_categorical_accuracy: 0.7757
# Epoch 116/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7330 - sparse_top_k_categorical_accuracy: 0.8049 - val_loss: 2.3700 - val_sparse_top_k_categorical_accuracy: 0.7737
# Epoch 117/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7617 - sparse_top_k_categorical_accuracy: 0.7983 - val_loss: 2.4034 - val_sparse_top_k_categorical_accuracy: 0.7676
# Epoch 118/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7726 - sparse_top_k_categorical_accuracy: 0.8011 - val_loss: 2.4143 - val_sparse_top_k_categorical_accuracy: 0.7594
# Epoch 119/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7881 - sparse_top_k_categorical_accuracy: 0.8051 - val_loss: 2.3438 - val_sparse_top_k_categorical_accuracy: 0.7661
# Epoch 120/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7589 - sparse_top_k_categorical_accuracy: 0.8103 - val_loss: 2.3713 - val_sparse_top_k_categorical_accuracy: 0.7650
# Epoch 121/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8122 - sparse_top_k_categorical_accuracy: 0.7981 - val_loss: 2.3996 - val_sparse_top_k_categorical_accuracy: 0.7737
# Epoch 122/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7903 - sparse_top_k_categorical_accuracy: 0.7994 - val_loss: 2.4620 - val_sparse_top_k_categorical_accuracy: 0.7564
# Epoch 123/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.9055 - sparse_top_k_categorical_accuracy: 0.7867 - val_loss: 2.3695 - val_sparse_top_k_categorical_accuracy: 0.7757
# Epoch 124/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7734 - sparse_top_k_categorical_accuracy: 0.7994 - val_loss: 2.3764 - val_sparse_top_k_categorical_accuracy: 0.7752
# Epoch 125/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7628 - sparse_top_k_categorical_accuracy: 0.8050 - val_loss: 2.3607 - val_sparse_top_k_categorical_accuracy: 0.7762
# Epoch 126/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7827 - sparse_top_k_categorical_accuracy: 0.8009 - val_loss: 2.3205 - val_sparse_top_k_categorical_accuracy: 0.7742
# Epoch 127/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7783 - sparse_top_k_categorical_accuracy: 0.8005 - val_loss: 2.3532 - val_sparse_top_k_categorical_accuracy: 0.7722
# Epoch 128/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7646 - sparse_top_k_categorical_accuracy: 0.7943 - val_loss: 2.3462 - val_sparse_top_k_categorical_accuracy: 0.7727
# Epoch 129/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8010 - sparse_top_k_categorical_accuracy: 0.7945 - val_loss: 2.4085 - val_sparse_top_k_categorical_accuracy: 0.7630
# Epoch 130/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8563 - sparse_top_k_categorical_accuracy: 0.7850 - val_loss: 2.3698 - val_sparse_top_k_categorical_accuracy: 0.7757
# Epoch 131/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7423 - sparse_top_k_categorical_accuracy: 0.8034 - val_loss: 2.3862 - val_sparse_top_k_categorical_accuracy: 0.7691
# Epoch 132/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7571 - sparse_top_k_categorical_accuracy: 0.8028 - val_loss: 2.3494 - val_sparse_top_k_categorical_accuracy: 0.7778
# Epoch 133/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7324 - sparse_top_k_categorical_accuracy: 0.7978 - val_loss: 2.4381 - val_sparse_top_k_categorical_accuracy: 0.7569
# Epoch 134/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7825 - sparse_top_k_categorical_accuracy: 0.7989 - val_loss: 2.3524 - val_sparse_top_k_categorical_accuracy: 0.7701
# Epoch 135/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7170 - sparse_top_k_categorical_accuracy: 0.8083 - val_loss: 2.3653 - val_sparse_top_k_categorical_accuracy: 0.7691
# Epoch 136/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8042 - sparse_top_k_categorical_accuracy: 0.7929 - val_loss: 2.3982 - val_sparse_top_k_categorical_accuracy: 0.7701
# Epoch 137/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8155 - sparse_top_k_categorical_accuracy: 0.7937 - val_loss: 2.3564 - val_sparse_top_k_categorical_accuracy: 0.7788
# Epoch 138/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7566 - sparse_top_k_categorical_accuracy: 0.8026 - val_loss: 2.3964 - val_sparse_top_k_categorical_accuracy: 0.7650
# Epoch 139/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7999 - sparse_top_k_categorical_accuracy: 0.7922 - val_loss: 2.3808 - val_sparse_top_k_categorical_accuracy: 0.7717
# Epoch 140/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7503 - sparse_top_k_categorical_accuracy: 0.8105 - val_loss: 2.3825 - val_sparse_top_k_categorical_accuracy: 0.7722
# Epoch 141/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7675 - sparse_top_k_categorical_accuracy: 0.7933 - val_loss: 2.3773 - val_sparse_top_k_categorical_accuracy: 0.7803
# Epoch 142/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7471 - sparse_top_k_categorical_accuracy: 0.8078 - val_loss: 2.3717 - val_sparse_top_k_categorical_accuracy: 0.7752
# Epoch 143/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7931 - sparse_top_k_categorical_accuracy: 0.7951 - val_loss: 2.3292 - val_sparse_top_k_categorical_accuracy: 0.7737
# Epoch 144/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7429 - sparse_top_k_categorical_accuracy: 0.8015 - val_loss: 2.3054 - val_sparse_top_k_categorical_accuracy: 0.7839
# Epoch 145/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7254 - sparse_top_k_categorical_accuracy: 0.8044 - val_loss: 2.3522 - val_sparse_top_k_categorical_accuracy: 0.7783
# Epoch 146/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.8371 - sparse_top_k_categorical_accuracy: 0.7880 - val_loss: 2.3739 - val_sparse_top_k_categorical_accuracy: 0.7645
# Epoch 147/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7664 - sparse_top_k_categorical_accuracy: 0.8070 - val_loss: 2.3347 - val_sparse_top_k_categorical_accuracy: 0.7757
# Epoch 148/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7486 - sparse_top_k_categorical_accuracy: 0.8053 - val_loss: 2.3359 - val_sparse_top_k_categorical_accuracy: 0.7722
# Epoch 149/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7710 - sparse_top_k_categorical_accuracy: 0.7995 - val_loss: 2.3598 - val_sparse_top_k_categorical_accuracy: 0.7783
# Epoch 150/150
# 491/491 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 1.7844 - sparse_top_k_categorical_accuracy: 0.7973 - val_loss: 2.3638 - val_sparse_top_k_categorical_accuracy: 0.7752

# %% [markdown]
# Extraction statistics

# %%
train_loss = history.history['loss']
val_loss = history.history['val_loss']
train_accuracy = history.history['sparse_top_k_categorical_accuracy']
val_accuracy = history.history['val_sparse_top_k_categorical_accuracy']
epochs = range(1, len(train_loss) + 1)

# %% [markdown]
# Graphs

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Loss
plt.subplot(1, 2, 1)
plt.plot(epochs, train_loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss During Training and Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracy, label='Training Accuracy')
plt.plot(epochs, val_accuracy, label='Validation Accuracy')
plt.title('Accuracy During Training and Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Model evaluation

# %%
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")
# Out:
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.3630 - sparse_top_k_categorical_accuracy: 0.7916
# Test Loss: 2.363799571990967
# Test Accuracy: 0.7752293348312378

# %% [markdown]
# Saving the model

# %%
model.save("rnn_model.keras")

# %% [markdown]
# Saving the tokenizer

# %%
import pickle

with open("rnn_tokenizer.pkl", "wb") as f:
    pickle.dump(tokenizer, f)
